# %% [markdown]
#  <div style="background-color:#a9dce3; padding:10px; text-align:center; box-shadow: 5px 5px 10px #888888; border-radius: 10px;">
#     <font color="#7689de">
#         <h1><b>Practical Training CRE 1: Residence Time Distribution</b></h1>
#     </font>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# ####  <font color=007BFF> Platte, Perez Bolde </font>

# %% [markdown]
# #### *<font color="#8AAA79">Residence Time Distribution</font>*

# %% [markdown]
# # <center> <b><font color=A541FD> Preparation for the Practical Training </font></b> </center>

# %% [markdown]
# # <font color=FF4500> Relevant Lecture Contents </font>

# %%
# %run Resources/MoleBalance.ipynb
# Out:
#         <iframe
#             width="75%"
#             height="600"
#             src="Resources/PDF files/Mole Balance-6-26.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# %run Resources/Video1.ipynb

# %% [markdown]
# # <font color=1CB0F6> Lab Script </font>

# %%
# %run Resources/LabScript.ipynb
# Out:
#         <iframe
#             width="75%"
#             height="600"
#             src="Resources/PDF files/scriptCRE1.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # <font color=1CB0F6> The Chemical Reactor System </font>

# %%
# %run Resources/VideoChemicalReactor.ipynb
# Out:
# <video width='600' controls><source src='Resources/Videos/CRE1-The Chemical Reactor System.mp4' type='video/mp4'></video>

# %% [markdown]
# # <font color=FF4500> Preparation Questions </font>

# %%
# %run Resources/PreparationQuestions.ipynb
# Out:
#         <iframe
#             width="75%"
#             height="600"
#             src="Resources/PDF files/Preparation Questions (1).pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
#  <div style="background-color:#7689de; padding:5px; text-align:center; box-shadow: 5px 5px 10px #888888; border-radius: 10px;">
# </div>

# %% [markdown]
# # <center> <font color=FF4500> Making of the Lab Report </font> </center>

# %% [markdown]
# ## <font color=1CB0F6> Basics of Excel </font>

# %%
# %run Resources/VideoExcel.ipynb

# %% [markdown]
# ## <font color=A541FD>  1.	 Open the saved file
# titled CRE1-GroupN-RunN. In this case the data was opened on Notepad and later copied onto an Excel sheet.

# %% [markdown]
# ![image.png](attachment:f2597b2c-3a0a-4948-a4df-2a70cc1a1776.png)

# %% [markdown]
# ## <font color=A541FD>  2. Correct time to seconds
#    As the time is given in hh:mm:ss, use the following formula to determine how many seconds that is:

# %% [markdown]
# ![image.png](attachment:236632e3-aba8-457f-8317-ccf4d6f90534.png)

# %% [markdown]
# ## <font color=A541FD> 3.	Determine Δt
# Subtract the initial time in seconds to each total value to determine Δt:

# %% [markdown]
# ![image.png](attachment:1677afb1-67d6-4e34-8513-071350aa5764.png)

# %% [markdown]
# ## <font color=A541FD>  4.	Insert the original data
# and the calculated time in seconds.
# Note:
# * for the groups that used the older version of the CSTR, the Δt is not constant. After consulting, it was determined that this difference must be disregarded and Δt must be changed !
# * for groups that used a PFR, an F(t)

# %% [markdown]
# ![image.png](attachment:f1c4ec44-96c1-4310-ba04-3f7a1ef37b78.png)

# %% [markdown]
# ## <font color=A541FD>  5. Plot F(t) curve
# After inserting the data, an F(t) curve will be plotted:

# %%
# %run Resources/VideoRTD.ipynb
# Out:
# <video width='600' controls start='150'><source src='Resources/Videos/CRE1-RTD.mp4' type='video/mp4'></video>

# %% [markdown]
# ![image.png](attachment:aae1d742-6411-4759-8f2a-0dfe13551a1f.png)

# %% [markdown]
# ## <font color=A541FD>  6. Identify:
# From the obtained plot, the conductivity of water (A) and the maximum conductivity (B) must be identified, as well as the start time (C) and the end time (D).

# %% [markdown]
# ![image.png](attachment:c686131f-6350-43ba-b553-493dae1a480f.png)

# %% [markdown]
# ## <font color=A541FD>  7. Trim and Adjust
# After trimming and adjusting based on the values determined on the previous step, a new F(t) curve is obtained:
# (Note: do not normalize in this step)

# %% [markdown]
# ![image.png](attachment:0a5e62f6-0b09-4ea8-b101-bebec75a9ad4.png)

# %% [markdown]
# ## <font color=A541FD> 8.	Smooth
# *What do we do when we smoothen a curve?*
# The Smooth Curve action smooths out sharp changes in direction in a curve. It is used to eliminate some of the fluctuations caused by noise in the data set.
# In this case, the OFFSET function is used to take every fifth value of time and conductivity and plot them.

# %% [markdown]
# # Take care of the timestamp

# %%
# %run Resources/SmoothVideo.ipynb

# %% [markdown]
# ![image.png](attachment:f8a34149-156d-4888-b3f9-751c035a81c1.png)

# %% [markdown]
# ## <font color=A541FD> 9.	Numerical Derivation:
# The formulas needed to derive F(t) to obtain E(t) are given:

# %%
# %run Resources/NumericalDerivation.ipynb
# Out:
#         <iframe
#             width="600"
#             height="360"
#             src="https://www.youtube.com/embed/D2GvGqF5DAU?start=560"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# 3-point midpoint:
# ![image.png](attachment:70674d16-e865-4c8e-9a27-02e97836292b.png)

# %% [markdown]
# 5- point stencil:
# ![image.png](attachment:e2e6c639-a00e-4677-a105-1ef97ae315f5.png)

# %% [markdown]
# ## <font color=A541FD>  10.	Identify the Maximum Conductivity
# A plot is obtained, from which the maximum value (Max. Conductivity) must be identified.

# %% [markdown]
# ![image.png](attachment:6e30995a-9bfd-4aff-b360-c8c02e4649ab.png)

# %% [markdown]
# ## <font color=A541FD>  11. Normalize
# What does normalizing mean?
#
#
# When we normalize the data, we organize it in a scale or range. In this case, the IF function can be used to organize the data between 0 (lowest value) and 1 (highest value).

# %%
# %run Resources/NormalizeVideo.ipynb

# %% [markdown]
# ![image.png](attachment:00aae715-de2b-473b-8d7e-fc99e2d143ba.png)

# %% [markdown]
# ## <font color=A541FD> 12. Convert
# Calculate tdi and E(tdi) following by using the formulas provided in the excel sheet.

# %% [markdown]
# ![image.png](attachment:3541fec9-281a-4f8f-8890-b72ed88e3932.png)

# %% [markdown]
# ## <font color=A541FD>  13. Integrate, Multiply, Integrate

# %% [markdown]
# ![image.png](attachment:13903a23-c25f-4264-8447-ba43187ac69f.png)

# %% [markdown]
# ## <font color=A541FD>  14. Find t-bar

# %% [markdown]
# ![image.png](attachment:907ed24d-7469-4ddf-8c8e-30f39ed15a2f.png)

# %% [markdown]
# ## <font color=A541FD>  15. Multiply and Integrate

# %% [markdown]
# ![image.png](attachment:26a52ac0-92b6-4115-9760-abe872dec94f.png)

# %% [markdown]
# ## <font color=A541FD>  16. Sigma (Standard Deviation)

# %% [markdown]
# ![image.png](attachment:e8d82f8b-787c-4b03-86f8-243c256ea7ab.png)
# ![image.png](attachment:ab29c8b6-7a46-4204-ba41-5fcdd3957a87.png)
